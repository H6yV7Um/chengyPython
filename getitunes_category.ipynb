# %%
import  requests

# %%
file =open('urls.txt')
url_dicts={}
for row in file.readlines():
    infos=row.split('\t')
    url_dicts[infos[1]]=infos[0]
print(url_dicts)
# Out:
# {'73862\n': 'us/podcast/lions-anonymous-podcast-feed/id913317242', '81655\n': 'us/podcast/gassed/id1314214848', '141214\n': 'us/podcast/ag/id592453119', '141420\n': 'us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id415707254', '110764\n': 'us/podcast/pizza-rat-diaries/id1304743231', '104181\n': 'us/podcast/conversations-in-complexity/id1223828923', '85616\n': 'us/podcast/picture-talk/id347808995', '74115\n': 'us/podcast/e-beautyrunsdeep-thepodcast/id1273606765', '126889\n': 'us/podcast/volume-speaker/id1237004662', '119729\n': 'us/podcast/shadhili-dhikr/id1033339915', '80284\n': 'us/podcast/zm-night-show/id1126543548', '120329\n': 'us/podcast/beit-shalom-%D0%B1%D0%B5%D0%B9%D1%82-%D1%88%D0%B0%D0%BB%D0%BE%D0%BC/id756548943', '130215\n': 'us/podcast/ua-%D1%85%D0%B2%D0%B8%D0%BB%D1%8F-%D0%BA%D0%BE%D0%BB%D0%BE%D1%80%D0%B0%D0%B4%D0%BE/id1058250345', '139317\n': 'us/podcast/kb-proper-trance/id1090431347', '94074\n': 'us/podcast/vicious-mockery/id1281071668', '89797\n': 'us/podcast/rus-car-talk/id
# ...

# %%
file = open('urls.txt')
url_dicts = {}
for row in file.readlines():
    infos = row.strip('\n').split('\t')
    url_dicts[infos[1]] = infos[0]
print(url_dicts)
# Out:
# {'73862': 'us/podcast/lions-anonymous-podcast-feed/id913317242', '120329': 'us/podcast/beit-shalom-%D0%B1%D0%B5%D0%B9%D1%82-%D1%88%D0%B0%D0%BB%D0%BE%D0%BC/id756548943', '74115': 'us/podcast/e-beautyrunsdeep-thepodcast/id1273606765', '141420': 'us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id415707254', '141214': 'us/podcast/ag/id592453119', '110764': 'us/podcast/pizza-rat-diaries/id1304743231', '115061': 'us/podcast/tacticaltalkradios-podcast/id1253465014', '86295': 'us/podcast/yusuf/id972094672', '121589': 'us/podcast/higher-ideas-podcast/id572882113', '126107': 'us/podcast/nerd-goggles-podcast/id562487180', '109720': 'us/podcast/scott-andersons-warrior-academy/id732660249', '137736': 'us/podcast/a9-podcast/id447437880', '120694': 'us/podcast/ajnahuasca/id1294148048', '118440': 'us/podcast/we-love-philly-radio/id279063466', '73494': 'us/podcast/animalators/id1049348704', '86298': 'us/podcast/zahraun-podcast/id934114819', '129796': 'us/podcast/on-the-road-with-kc-and-alex-road-trips/id45
# ...

# %%
pre_url='https://itunes.apple.com/'
for k,v in url_dicts.items():
    url=pre_url+v
    print(url)
# Out:
# https://itunes.apple.com/us/podcast/lions-anonymous-podcast-feed/id913317242
# https://itunes.apple.com/us/podcast/beit-shalom-%D0%B1%D0%B5%D0%B9%D1%82-%D1%88%D0%B0%D0%BB%D0%BE%D0%BC/id756548943
# https://itunes.apple.com/us/podcast/e-beautyrunsdeep-thepodcast/id1273606765
# https://itunes.apple.com/us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id415707254
# https://itunes.apple.com/us/podcast/ag/id592453119
# https://itunes.apple.com/us/podcast/pizza-rat-diaries/id1304743231
# https://itunes.apple.com/us/podcast/tacticaltalkradios-podcast/id1253465014
# https://itunes.apple.com/us/podcast/yusuf/id972094672
# https://itunes.apple.com/us/podcast/higher-ideas-podcast/id572882113
# https://itunes.apple.com/us/podcast/nerd-goggles-podcast/id562487180
# https://itunes.apple.com/us/podcast/scott-andersons-warrior-academy/id732660249
# https://itunes.apple.com/us/podcast/a9-podcast/id447437880
# https://itunes.apple.com/us/podcast/ajnahuasca/id1294148048
# ...

# %%
html=requests.get('https://itunes.apple.com/us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id560780299')

# %%
type(html)
# Out:
# requests.models.Response

# %%
type(html.text)
# Out:
# str

# %%
import beautifulsoup4
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-e646caa245dd> in <module>()
# ----> 1 import beautifulsoup4
#
# ImportError: No module named 'beautifulsoup4'

# %%
import bs4

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(html.text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
soup.select("#intro")
# Out:
# []

# %%
html.text
# Out:
# ''

# %%
html=requests.get('https://itunes.apple.com/us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id560780299')

# %%
soup=BeautifulSoup(html.text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
soup.select("#intro")
# Out:
# []

# %%
html=requests.get('https://itunes.apple.com/us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id560780299')

# %%
html.text
# Out:
# ''

# %%
html.headers
# Out:
# {'x-apple-jingle-correlation-key': 'XUDS367LOD4FIU5AFGSQFLW6WY', 'X-Apple-Partner': 'origin.0', 'x-apple-application-site': 'NWK', 'Vary': 'Cookie, X-Apple-Store-Front, Accept-Encoding', 'x-webobjects-loadaverage': '0', 'apple-seq': '0', 'x-apple-orig-url': 'https://itunes.apple.com/us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id560780299', 'x-apple-request-uuid': 'bd072dfb-eb70-f854-53a0-29a502aedeb6', 'Cache-Control': 'public,no-transform,max-age=60', 'X-Cache': 'MISS from cache.51cdn.com', 'Access-Control-Allow-Origin': '*', 'X-Cache-Remote': 'TCP_MISS from a184-27-178-191.deploy.akamaitechnologies.com (AkamaiGHost/9.1.4.4-21488373) (-)', 'Connection': 'close', 'Last-Modified': 'Thu, 11 Jan 2018 10:19:51 GMT', 'apple-timing-app': '2 ms', 'apple-originating-system': 'MZStore', 'user-country': 'CN', 'x-apple-application-instance': '1013301', 'x-frame-options': 'SAMEORIGIN', 'x-apple-translated-wo-url': '/WebObjects/MZStore.woa/wa/viewPodcast?id=560780299&cc=us&urlDesc=/%D8%B4%D9%8A%D9%
# ...

# %%
html.ok
# Out:
# False

# %%
proxies = {
  "http": "http://127.0.0.1:51263",
  "https": "http://127.0.0.1:51263",
}
html=requests.get('https://itunes.apple.com/us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id560780299',proxies=proxies)

# %%
html.text
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">\n<html prefix="og: http://ogp.me/ns#" xmlns="http://www.apple.com/itms/" lang="en">\n\n\n  <head>\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta name="keywords" content="شيلات, ابوعبدالله, Music, Podcasts, podcast, itunes" /><meta name="description" content="Download past episodes or subscribe to future episodes of شيلات by ابوعبدالله for free." /><meta name="platform-cache-id" content="8" /><meta name="apple:content_id" content="560780299" /><meta content="شيلات by ابوعبدالله on Apple Podcasts" property="og:title" /><meta content="Download past episodes or subscribe to future episodes of شيلات by ابوعبدالله for free." property="og:description" /><meta content="Apple Podcasts" property="og:site_name" /><meta name="twitter:title" content="شيلات by ابوعبدالله on Apple Podcasts" /><meta name="twitter:description" content="Download past episodes or subscribe t
# ...

# %%
soup=BeautifulSoup(html.text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
soup.select("#intro")
# Out:
# []

# %%
html.text
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">\n<html prefix="og: http://ogp.me/ns#" xmlns="http://www.apple.com/itms/" lang="en">\n\n\n  <head>\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta name="keywords" content="شيلات, ابوعبدالله, Music, Podcasts, podcast, itunes" /><meta name="description" content="Download past episodes or subscribe to future episodes of شيلات by ابوعبدالله for free." /><meta name="platform-cache-id" content="8" /><meta name="apple:content_id" content="560780299" /><meta content="شيلات by ابوعبدالله on Apple Podcasts" property="og:title" /><meta content="Download past episodes or subscribe to future episodes of شيلات by ابوعبدالله for free." property="og:description" /><meta content="Apple Podcasts" property="og:site_name" /><meta name="twitter:title" content="شيلات by ابوعبدالله on Apple Podcasts" /><meta name="twitter:description" content="Download past episodes or subscribe t
# ...

# %%
soup.select(".intro")
# Out:
# [<p class="intro has-preview-capable-text" preview-capable-text="We are unable to find iTunes on your computer. To download and subscribe to شيلات by ابوعبدالله, get iTunes now.">
#          We are unable to find iTunes on your computer. To download and subscribe to شيلات by ابوعبدالله, get iTunes now.
#        </p>, <div class="intro" id="title">
#            <div class="left">
#              <h1>شيلات</h1>
#              <h2>By ابوعبدالله</h2>
#            </div>
#            <div class="right">
#
#            </div>
#            <p>To listen to an audio podcast, mouse over the title and click Play. Open iTunes to download and subscribe to podcasts.</p>
#          </div>]

# %%
soup.select("#title")
# Out:
# [<div class="intro" id="title">
#            <div class="left">
#              <h1>شيلات</h1>
#              <h2>By ابوعبدالله</h2>
#            </div>
#            <div class="right">
#
#            </div>
#            <p>To listen to an audio podcast, mouse over the title and click Play. Open iTunes to download and subscribe to podcasts.</p>
#          </div>]

# %%
soup.select("#title").h2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-b9767f680e4f> in <module>()
# ----> 1 soup.select("#title").h2
#
# AttributeError: 'list' object has no attribute 'h2'

# %%
soup.select("#title")[0].h2
# Out:
# <h2>By ابوعبدالله</h2>

# %%
soup.select("#title").h2.html
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-57366e62a7a6> in <module>()
# ----> 1 soup.select("#title").h2.html
#
# AttributeError: 'list' object has no attribute 'h2'

# %%
soup.select("#title")[0].h2.html

# %%
soup.select("#title")[0].h2
# Out:
# <h2>By ابوعبدالله</h2>

# %%
soup.select("#title")[0].h2.html

# %%
soup.select("#title")[0].h2.text
# Out:
# 'By ابوعبدالله'

# %%
soup.select("#title")[0].h2.text.strip('By ')
# Out:
# 'ابوعبدالله'

# %%
pre_url='https://itunes.apple.com/'
for k,v in url_dicts.items():
    url=pre_url+v
    print(url)
    r=requests.get(url,proxies=proxies)
# Out:
# https://itunes.apple.com/us/podcast/lions-anonymous-podcast-feed/id913317242
# https://itunes.apple.com/us/podcast/beit-shalom-%D0%B1%D0%B5%D0%B9%D1%82-%D1%88%D0%B0%D0%BB%D0%BE%D0%BC/id756548943
# https://itunes.apple.com/us/podcast/e-beautyrunsdeep-thepodcast/id1273606765
# https://itunes.apple.com/us/podcast/%D8%B4%D9%8A%D9%84%D8%A7%D8%AA/id415707254
# https://itunes.apple.com/us/podcast/ag/id592453119
# https://itunes.apple.com/us/podcast/pizza-rat-diaries/id1304743231
# https://itunes.apple.com/us/podcast/tacticaltalkradios-podcast/id1253465014
# https://itunes.apple.com/us/podcast/yusuf/id972094672
# https://itunes.apple.com/us/podcast/higher-ideas-podcast/id572882113
# https://itunes.apple.com/us/podcast/nerd-goggles-podcast/id562487180
# https://itunes.apple.com/us/podcast/scott-andersons-warrior-academy/id732660249
# https://itunes.apple.com/us/podcast/a9-podcast/id447437880
# https://itunes.apple.com/us/podcast/ajnahuasca/id1294148048
# ...

# %%
pre_url='https://itunes.apple.com/'
name_dict={}
for k,v in url_dicts.items():
    url=pre_url+v
    print(url)
    r=requests.get(url,proxies=proxies)
    soup=BeautifulSoup(r.text)
    name=soup.select("#title")[0].h2.text.strip('By ')
    name_dict[k]=name
# Out:
# https://itunes.apple.com/us/podcast/lions-anonymous-podcast-feed/id913317242
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# https://itunes.apple.com/us/podcast/beit-shalom-%D0%B1%D0%B5%D0%B9%D1%82-%D1%88%D0%B0%D0%BB%D0%BE%D0%BC/id756548943
# https://itunes.apple.com/us/podcast/e-beautyrunsdeep-thepodcast/id1273606765
# ...

# %%
name_dict
# Out:
# {'102574': 'Ука Төмөр',
#  '104181': 'H',
#  '109415': 'H',
#  '109720': 'DP',
#  '110764': 'K$',
#  '111463': 'E',
#  '112165': 'RÚV',
#  '115061': 'T',
#  '116955': 'G+P',
#  '118440': 'Q',
#  '119729': 'الصلاة والسلام عليك يا سيدَنا يا محمد',
#  '120329': 'Александр Огиенко',
#  '120694': 'JC',
#  '121589': "'i'",
#  '125038': 'F',
#  '126107': 'MJ',
#  '126889': 'TQ',
#  '129352': 'AP',
#  '129796': 'KC',
#  '130215': 'UA Хвиля Колорадо',
#  '133805': 'KT',
#  '134375': 'MM',
#  '137736': 'A9',
#  '139317': 'K',
#  '139601': 'bg',
#  '139854': 'OJ',
#  '141214': 'AG',
#  '141414': 'ابوعبدالله',
#  '141420': 'Unknown',
#  '142310': 'DJ ПАША КОРЕЕЦ',
#  '142416': 'اناشيد',
#  '142767': 'E',
#  '142908': 'OM',
#  '143705': 'Dj Сухов',
#  '73494': 'IV',
#  '73862': 'M',
#  '74115': 'PT',
#  '78907': 'CD',
#  '79301': '"ME"',
#  '80284': 'ZM',
#  '81655': 'TJ',
#  '85616': 'NL',
#  '86295': 'Мавлоно Муҷибураҳмони Ансорӣ',
#  '86298': 'سماحة الشيخ الغزّي',
#  '89797': 'Ru',
# ...

# %%
len(name_dict)
# Out:
# 47

# %%
len(url_dicts)
# Out:
# 47

# %%
html =requests.get("https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/",proxies=proxies).text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dac3cec435be> in <module>()
# ----> 1 html =requests.get("https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/",proxies=proxies).text
#
# NameError: name 'requests' is not defined

# %%
import requests
from bs4 import BeautifulSoup

proxies = {
    "http": "http://127.0.0.1:51263",
    "https": "http://127.0.0.1:51263",
}
html=requests.get("https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/",proxies=proxies).text

# %%
len(html)
# Out:
# 264646

# %%
soup=BeautifulSoup(html)

a_tag_list=soup.select('.hebrewScriptures')[0].select('a')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
a_tag_list
# Out:
# [<a class="colorThree bibleBook hasAudio first" href="/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/">
#                                <span class="tocIcons">
#                                   <div class="iconAudio"></div>
#                                   <div class="iconStudyNote"></div>
#                                </span>
#                                <span class="fullName">創世記</span>
#                                <span class="abbrName">創</span>
#                             </a>,
#  <a class="colorThree bibleBook hasAudio " href="/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%87%BA%E3%82%A8%E3%82%B8%E3%83%97%E3%83%88%E8%A8%98/">
#                                <span class="tocIcons">
#                                   <div class="iconAudio"></div>
#                                   <div class="iconStudyNote"></div>
#                                </span>
# ...

# %%
page_list=[]
for a_tag in a_tag_list:
    page_list.append(a_tag['href'])
page_list
# Out:
# ['/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%87%BA%E3%82%A8%E3%82%B8%E3%83%97%E3%83%88%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E3%83%AC%E3%83%93%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E6%B0%91%E6%95%B0%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E7%94%B3%E5%91%BD%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E3%83%A8%E3%82%B7%E3%83%A5%E3%82%A2/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E8%A3%81%E3%81%8D%E4%BA%BA/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E3%83%AB%E3%83%84/',
# ...

# %%
pre_url='https://www.jw.org'

# %%
for post_url in page_list:
    post_url=pre_url+post_url

# %%
page_list
# Out:
# ['/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%87%BA%E3%82%A8%E3%82%B8%E3%83%97%E3%83%88%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E3%83%AC%E3%83%93%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E6%B0%91%E6%95%B0%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E7%94%B3%E5%91%BD%E8%A8%98/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E3%83%A8%E3%82%B7%E3%83%A5%E3%82%A2/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E8%A3%81%E3%81%8D%E4%BA%BA/',
#  '/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E3%83%AB%E3%83%84/',
# ...

# %%
real_url_list=[]
for post_url in page_list:
    real_url_list.append(pre_url+post_url)

# %%
real_url_list
# Out:
# ['https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%87%BA%E3%82%A8%E3%82%B8%E3%83%97%E3%83%88%E8%A8%98/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E3%83%AC%E3%83%93%E8%A8%98/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E6%B0%91%E6%95%B0%E8%A8%98/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E7%94%B3%E5%91%BD%E8%A8%98/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E3%83%A8%E3%82%B7%E3%83%A5%E3%82%A2/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E8%A3%81%E3%81%8D%E4%BA%BA/',
# ...

# %%
book_page=real_url_list[0]

# %%
 book_page
# Out:
# 'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/'

# %%
html=requests.get(book_page,proxies=proxies)

# %%
soup =BeautifulSoup(html.text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
a_tag_list=soup.select('.chapters')[0].select('a')

# %%
chapter_url_list=[]
for a_tag in a_tag_list:
    chapter_url_list.append(pre_url+a_tag['href'])

# %%
chapter_url_list
# Out:
# ['https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/1/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/2/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/3/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/4/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/5/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/6/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/7/',
# ...

# %%
chapter_url=chapter_url_list[0]
html = requests.get(chapter_url, proxies=proxies).text
soup = BeautifulSoup(html)
title=soup.select('#article > article > header > h1')[0].text
print(title)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
#
#       創世記 1：1‐31

# %%
title
# Out:
# '\n   \n      創世記\xa01：1‐31\n   \n'

# %%
title.strip('\n')
# Out:
# '   \n      創世記\xa01：1‐31\n   '

# %%
title
# Out:
# '\n   \n      創世記\xa01：1‐31\n   \n'

# %%
title=title.strip('\n').strip('\n')

# %%
title
# Out:
# '   \n      創世記\xa01：1‐31\n   '

# %%
title.strip('  ')
# Out:
# '\n      創世記\xa01：1‐31\n'

# %%
title.strip('\n')
# Out:
# '   \n      創世記\xa01：1‐31\n   '

# %%
title.strip('  ').strip('\n')
# Out:
# '      創世記\xa01：1‐31'

# %%
title.strip('  ').strip('\n').strip('  ')
# Out:
# '創世記\xa01：1‐31'

# %%
title=title.strip('  ').strip('\n').strip('  ')

# %%
title
# Out:
# '創世記\xa01：1‐31'

# %%
string = title.replace(u'\xa0', u' ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-e0abcf145d1f> in <module>()
# ----> 1 string = string.replace(u'\xa0', u' ')
#
# NameError: name 'string' is not defined

# %%
title = title.replace(u'\xa0', u' ')

# %%
title
# Out:
# '創世記 1：1‐31'

# %%
url=soup.select("#streamingAudio > div > audio")[0]['href']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-4f4963bf43a5> in <module>()
# ----> 1 url=soup.select("#streamingAudio > div > audio")[0]['href']
#
# IndexError: list index out of range

# %%
soup.select("#streamingAudio > div > audio")
# Out:
# []

# %%
title=soup.select('#article > article > header > h1')[0].text

# %%
title
# Out:
# '\n   \n      創世記\xa01：1‐31\n   \n'

# %%
title.strip('\n').strip('  ').strip('\n')
# Out:
# '      創世記\xa01：1‐31'

# %%
title=title.strip('\n').strip('  ').strip('\n').strip('  ')

# %%
title
# Out:
# '創世記\xa01：1‐31'

# %%
title = title.replace(u'\xa0', u' ')

# %%
title
# Out:
# '創世記 1：1‐31'

# %%
chapter_url_list
# Out:
# ['https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/1/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/2/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/3/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/4/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/5/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/6/',
#  'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/7/',
# ...

# %%
chapter_url
# Out:
# 'https://www.jw.org/ja/%E5%87%BA%E7%89%88%E7%89%A9/%E8%81%96%E6%9B%B8/bi12/%E5%90%84%E6%9B%B8/%E5%89%B5%E4%B8%96%E8%A8%98/1/'

# %%
from selenium import webdriver

# %%
browser=webdriver.Chrome()
browser.get(chapter_url)
browser.implicitly_wait(60)
soup=BeautifulSoup(browser.page_source,'lxml')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-196e901d265c> in <module>()
#       1 browser=webdriver.Chrome
# ----> 2 browser.get(chapter_url)
#       3 browser.implicitly_wait(60)
#       4 soup=BeautifulSoup(browser.page_source,'lxml')
#
# TypeError: get() missing 1 required positional argument: 'url'

# %%
browser=webdriver.Chrome()
browser.get(chapter_url)
browser.implicitly_wait(60)
soup=BeautifulSoup(browser.page_source,'lxml')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-50-39f7214d8d57> in <module>()
#       2 browser.get(chapter_url)
#       3 browser.implicitly_wait(60)
# ----> 4 soup=BeautifulSoup(browser.page_source,'lxml')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     163                     "Couldn't find a tree builder with the features you "
#     164                     "requested: %s. Do you need to install a parser library?"
# --> 165                     % ",".join(features))
#     166             builder = builder_class()
#     167             if not (original_features == builder.NAME or
#
# ...

# %%
browser=webdriver.Chrome()
browser.get(chapter_url)
browser.implicitly_wait(60)
soup=BeautifulSoup(browser.page_source)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
url=soup.select('#streamingAudio > div > audio')[0]['href']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-7e73cf7bd7c6> in <module>()
# ----> 1 url=soup.select('#streamingAudio > div > audio')[0]['href']
#
# IndexError: list index out of range

# %%
soup.select('#streamingAudio > div > audio')
# Out:
# []

# %%
browser=webdriver.Chrome()
browser.get(chapter_url)
browser.implicitly_wait(60)
soup=BeautifulSoup(browser.page_source)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
soup.select('#streamingAudio > div > audio')
# Out:
# []

# %%
soup.select('#streamingAudio > div > audio')
# Out:
# []

# %%
browser.page_source
# Out:
# '<!DOCTYPE html><!--[if (gt IE 9)|!(IE)]>--><html xmlns="http://www.w3.org/1999/xhtml" class="w3 md-history md-localstorage md-supports md-audio md-canvas md-canvastext md-video md-no-touchevents md-no-flexboxtweener md-flexbox md-flexboxlegacy md-no-overflowscrolling md-flexwrap md-csstransforms3d" lang="ja" dir="ltr" xml:lang="ja" prefix="og: http://ogp.me/ns#"><!--[endif]--><!--[if IE 9]>    <html class="ieAny ie9" lang="ja" dir="ltr" xml:lang="ja" prefix="og: http://ogp.me/ns#">     <![endif]--><head>\n      <meta charset="utf-8" />\n      <base href="https://www.jw.org/" /><!--[if lte IE 6]></base><![endif]-->\n      <title>創世記 1 | オンライン聖書 | 「新世界訳」</title>\n      <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n<meta name="keywords" content="創世記 1, 聖書, オンライン聖書, 新世界訳, nwt, エホバの証人" />\n<meta name="description" content="創世記&amp;nbsp;1：1‐31―聖書をオンラインで読んだり，無料でダウンロードしたりできます。「新世界訳聖書」はエホバの証人により発行されています。" />\n<link rel="alternate" type="text/html" title="Non liv yo k
# ...

# %%
soup.select('#streamingAudio')
# Out:
# [<div class="jsAudioPlayer jsMarkersEnabled excludePin jsAlwaysIncludeForPinHeight loading" data-highlighter_target="#article" id="streamingAudio">
#              <label class="jsPlayUppCaseLabel" style="display: none;">言語を選ぶ</label>
#
#
#                 <a class="streaming noJSHide jsMediaPlayer jsDownload jsMediaPlayerLoading" data-issuedate="" data-jsonurl="https://apps.jw.org/GETPUBMEDIALINKS?booknum=1&amp;output=json&amp;pub=bi12&amp;fileformat=MP3&amp;alllangs=0&amp;track=1&amp;langwritten=J&amp;txtCMSLang=J" href="https://www.jw.org/download/?booknum=1&amp;output=html&amp;pub=bi12&amp;fileformat=MP3&amp;alllangs=0&amp;track=1&amp;langwritten=J&amp;txtCMSLang=J&amp;isBible=0" id="mediaPlayer-8545" style="display: none;" target="_blank" title="再生またはダウンロード"></a>
#
#           </div>]

# %%
soup.select('#streamingAudio > div')
# Out:
# []

# %%
soup.select('#streamingAudio > div')
# Out:
# []

# %%
soup.select('#streamingAudio')[0].select('a')
# Out:
# [<a class="streaming noJSHide jsMediaPlayer jsDownload jsMediaPlayerLoading" data-issuedate="" data-jsonurl="https://apps.jw.org/GETPUBMEDIALINKS?booknum=1&amp;output=json&amp;pub=bi12&amp;fileformat=MP3&amp;alllangs=0&amp;track=1&amp;langwritten=J&amp;txtCMSLang=J" href="https://www.jw.org/download/?booknum=1&amp;output=html&amp;pub=bi12&amp;fileformat=MP3&amp;alllangs=0&amp;track=1&amp;langwritten=J&amp;txtCMSLang=J&amp;isBible=0" id="mediaPlayer-8545" style="display: none;" target="_blank" title="再生またはダウンロード"></a>]

# %%
soup.select('#streamingAudio')[0].select('audio')
# Out:
# []

# %%
browser=webdriver.Chrome()
browser.get(chapter_url)
browser.implicitly_wait(60)
soup=BeautifulSoup(browser.page_source)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
browser.find_element_by_name('audio')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-64-70262b823a47> in <module>()
# ----> 1 browser.find_element_by_name('audio')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_name(self, name)
#     485             element = driver.find_element_by_name('foo')
#     486         """
# --> 487         return self.find_element(by=By.NAME, value=name)
#     488
#     489     def find_elements_by_name(self, name):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     953         return self.execute(Command.FIND_ELEMENT, {
#     954             'using': by,
# --> 955             'value': value})['value']
#     956
#     957     def find_elements(self, by=By.ID, value=None):
#
# ...

# %%
import time
browser=webdriver.Chrome()
browser.get(chapter_url)
time.sleep(5)
soup=BeautifulSoup(browser.page_source)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
soup.select('audio')
# Out:
# [<audio preload="none" src="https://download-a.akamaihd.net/files/media_bible/b6/bi12_01_Ge_J_01.mp3"><p class="error" rv-text="literals.CMSPUBS.TxtPlayerFailed">申し訳ありませんが，メディアプレーヤーが再生できませんでした。</p></audio>]

# %%
soup.select('audio')[0]['src']
# Out:
# 'https://download-a.akamaihd.net/files/media_bible/b6/bi12_01_Ge_J_01.mp3'

# %%
audio_url=soup.select('audio')[0]['src']

# %%
audio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-d2d841b7f1f3> in <module>()
# ----> 1 audio
#
# NameError: name 'audio' is not defined

# %%
audio_url
# Out:
# 'https://download-a.akamaihd.net/files/media_bible/b6/bi12_01_Ge_J_01.mp3'

# %%
r = requests.get(audio_url) 
with open(title+".mp3", "wb") as code:
     code.write(r.content)

# %%
browser.quit()
